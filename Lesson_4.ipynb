# %% [markdown]
# ### Урок 4. Непрерывные случайные величины. Функция распределения и плотность распределения вероятностей. Равномерное и нормальное распределение. Центральная предельная теорема

# %% [markdown]
# #### Задача 1
#
# О непрерывной равномерно распределенной случайной величине B известно, что ее дисперсия равна 0.2. Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %%
import pandas as pd
import numpy as np

# %%
from scipy.stats import norm
from scipy import stats

# %%
a = 0.5
Dx = 0.2

# %% [markdown]
# Математическое ожидание и дисперсия равномерного распределения:
#
# $$M(X) = \dfrac{a + b}{2}, \text{ } D(X) = \dfrac{(b - a)^2}{12}.$$

# %% [markdown]
# Отсюда:
# $$b = \sqrt{D(X) \cdot 12} + a$$

# %%
b = (12*Dx)**0.5 + a
b
# Out:
# 2.049193338482967

# %% [markdown]
# Cреднее значение будет соответствовать математическому ожиданию:

# %%
Mx = (a+b)/2
Mx
# Out:
# 1.2745966692414834

# %% [markdown]
# Проверим:

# %%
samples = np.random.uniform(a, b, size=1000)
samples
# Out:
# array([1.66863114, 1.45718175, 1.76924638, 1.87374845, 1.75522183,
#        0.74171539, 1.24752591, 1.92892727, 1.65566863, 0.91679943,
#        1.10546132, 0.51189947, 1.11725455, 0.58281161, 1.53592356,
#        0.68837816, 1.1863635 , 1.46835247, 1.26468256, 1.03312515,
#        1.23402128, 0.74168772, 1.07995401, 0.5513398 , 1.56965035,
#        1.93536168, 1.15074433, 1.20377182, 0.90977919, 1.19580928,
#        0.52697354, 0.6681692 , 0.9673084 , 1.58518737, 0.53187156,
#        2.01713168, 1.26362699, 1.67194063, 0.89092146, 1.25297545,
#        1.62803486, 0.70555986, 0.59554071, 1.05103599, 0.84161484,
#        1.93195465, 1.76763584, 1.80667975, 1.1097157 , 0.58289806,
#        1.18021427, 1.78612257, 1.57930527, 1.10061766, 1.1710198 ,
#        1.46951244, 1.22934013, 1.49187309, 1.12109274, 0.76622302,
#        1.8996215 , 0.76274963, 1.07073634, 1.6930785 , 0.86994238,
#        1.3368396 , 1.43141718, 1.57281736, 0.88116639, 1.01039476,
#        1.56104138, 0.99929727, 1.07256995, 1.2737564 , 1.87386014,
#        0.91327545, 1.30864769, 1.17276575, 0.90427609, 0.90350016,
#        0.756125  , 1.50732828, 0.9140082 , 0.9769377 , 1.61351967,
#        1.21374232, 1.76467983, 1.7671718 , 0.9397274 , 1.02411804,
#        1.24392579, 1.65618481, 1.22067162, 1.45065497, 1.52868345,
#        1.05922172, 1.02401749, 0.82142674, 0.67865077, 0.95025932,
#        0.76991775, 1.40437195, 0.698387  , 1.61648473, 1.08747001,
#        1.16876219, 1.69033529, 0.82101539, 0.69392588, 0.97189479,
#        1.04260901, 1.64700569, 0.65298733, 2.00960507, 1.71802599,
#        1.58673892, 0.51313879, 0.60940534, 0.83995477, 1.99851501,
#        2.036785  , 1.88945595, 1.67209772, 1.60741951, 0.96470304,
#        1.69559992, 1.69126512, 1.18753462, 1.0562592 , 0.72667686,
#        1.81329541, 1.20391726, 1.22267782, 1.63043604, 0.70364882,
#        1.63521421, 1.17153853, 1.81455251, 1.65549403, 1.82635264,
#        1.46964082, 0.96802959, 0.97799422, 1.14955981, 1.37146609,
#        1.21332281, 0.77918894, 1.06493444, 1.39236403, 1.20412878,
#        0.56903527, 1.50830331, 1.38275199, 1.13078468, 0.75865602,
#        1.55818164, 1.86924213, 2.00370148, 0.77367526, 1.60873342,
#        1.0031277 , 1.21256919, 1.15785408, 1.25316846, 1.0966402 ,
#        2.01130044, 1.08170671, 1.57082199, 1.3036132 , 1.61639367,
#        1.55142679, 1.07243094, 1.32464932, 1.34022828, 1.43207873,
#        1.00365314, 1.99949964, 0.66827684, 2.02402667, 1.24387193,
#        1.25760685, 1.50770702, 1.68341192, 1.57384272, 0.63014601,
#        1.42629196, 0.78946934, 0.68874073, 1.48947197, 0.6698435 ,
#        0.87149477, 1.52405779, 0.92247235, 1.01852778, 1.00609757,
#        0.73818883, 1.51565286, 0.58220558, 1.70010615, 0.58087978,
#        1.09631632, 0.77281449, 1.60351868, 0.62696893, 0.70886267,
#        0.90992171, 1.24034574, 0.66317847, 0.68486541, 0.72296222,
#        1.78897889, 1.45743591, 2.04771949, 2.04099208, 0.96466173,
#        0.86062428, 1.44929861, 1.08582669, 1.23265591, 1.82422485,
#        1.23637021, 0.66765406, 1.01108404, 1.55273749, 0.71965632,
#        1.15353541, 1.27429586, 1.80069767, 1.50646061, 0.91484023,
#        0.75899721, 1.51516023, 1.09199261, 1.71236741, 1.02714692,
#        1.29796528, 0.77287215, 1.16068531, 1.8427426 , 0.79198406,
#        0.96210156, 1.45389673, 0.54747268, 1.00372999, 1.22659257,
#        1.38407456, 1.49599225, 1.94693546, 1.23820414, 1.84683583,
#        0.64260842, 0.90687769, 0.85822607, 0.61265149, 1.58307461,
#        1.08291789, 1.83622702, 1.71943848, 1.02033285, 1.30323467,
#        0.9901275 , 0.80330729, 1.87737736, 1.17102804, 1.74527362,
#        0.59319793, 0.61265888, 0.66834574, 1.48176652, 1.94286324,
#        1.79169399, 0.98519805, 1.03511201, 0.89417185, 1.31294562,
#        1.75067415, 1.58160904, 1.9692038 , 2.01316618, 0.53207299,
#        1.63736491, 0.54826641, 1.74256981, 1.1207384 , 1.17605022,
#        0.76129458, 1.21976204, 0.98992118, 0.85076257, 1.52828198,
#        0.7110379 , 1.56524964, 1.87453162, 1.74494987, 0.59015711,
#        0.86170359, 0.90430867, 1.82614241, 0.58185929, 2.03660348,
#        0.93702245, 1.46483996, 0.69759574, 1.94756065, 1.59824652,
#        1.82441085, 1.79091608, 1.64941872, 1.72441241, 1.32892822,
#        1.94789595, 0.58820374, 1.48219034, 0.64181008, 1.02866245,
#        1.62835819, 1.98814883, 1.10406892, 1.98553842, 1.6526373 ,
#        0.69443027, 0.66159034, 1.71164459, 1.54778142, 0.84236764,
#        1.31845018, 1.36611248, 0.81491406, 0.67128367, 0.73483395,
#        1.70413678, 1.22946353, 1.43556611, 1.50449798, 0.98286558,
#        0.60580327, 0.74368062, 1.95121492, 1.51134685, 1.99832566,
#        0.53546183, 1.29611778, 0.69329948, 0.56138662, 2.01684188,
#        1.05636102, 1.84118372, 1.4984836 , 0.7327747 , 1.11882342,
#        1.74810532, 1.29093313, 0.87721569, 1.03195165, 0.76980607,
#        1.79703627, 1.86911245, 2.04275672, 1.95772629, 1.9712996 ,
#        1.69743822, 1.95195704, 1.19859816, 1.38865857, 2.01843586,
#        1.71798641, 0.52982585, 1.21573553, 1.15552226, 1.11622611,
#        1.80397736, 1.88490351, 1.41792371, 2.0406005 , 1.39655464,
#        1.45014091, 0.91718062, 1.81063443, 1.08396295, 1.59373992,
#        1.59229971, 1.5178908 , 1.09510024, 1.13787337, 0.99073024,
#        1.51788805, 1.57108088, 0.88463437, 0.82316177, 1.99005135,
#        0.83013493, 0.95275182, 1.49855761, 0.86094995, 1.50989959,
#        1.96225536, 1.03316551, 1.0337228 , 1.86972316, 1.85034209,
#        2.02000941, 1.79906666, 2.0258707 , 1.09728739, 1.79280241,
#        1.93075186, 1.83567416, 1.44240026, 1.16201378, 1.98271666,
#        1.46116755, 1.40078394, 0.52354638, 1.10203826, 0.52379208,
#        2.0314959 , 1.84446252, 0.68728314, 1.91868176, 0.87178538,
#        1.49046618, 0.56783003, 1.81097421, 0.87841416, 1.37734412,
#        1.21847865, 0.68888421, 1.74570149, 1.17441954, 1.39523402,
#        1.90703719, 1.68532331, 1.05189141, 1.55062061, 1.19749751,
#        1.55972048, 0.56220155, 1.38062389, 0.74842458, 1.36751773,
#        0.84717515, 1.85487973, 1.16454991, 1.18938441, 0.77564903,
#        1.09772082, 0.52629784, 0.86412525, 0.77009525, 0.88282181,
#        1.80312842, 0.57246189, 2.02766009, 1.77520306, 1.69415332,
#        0.90044643, 0.78712911, 1.17827412, 1.05149531, 1.71135986,
#        1.67491353, 0.93794933, 1.35780254, 0.92045012, 0.56813693,
#        1.46759286, 1.68030381, 1.33838076, 1.24900233, 1.81680053,
#        1.25150961, 0.94294027, 1.67717601, 0.58880358, 1.0469465 ,
#        0.69394511, 0.69188469, 0.77444464, 1.52950836, 1.45567219,
#        1.11884673, 0.66717661, 1.78296187, 1.37336102, 1.73527159,
#        0.55097976, 0.96280712, 1.98996644, 1.65002498, 1.88699382,
#        1.73702311, 1.10711651, 0.52869331, 0.97912876, 1.97473885,
#        1.12972806, 1.51851256, 1.55302183, 0.53545746, 0.52968073,
#        0.5667087 , 2.04226721, 0.6234487 , 1.19235736, 1.24258085,
#        1.42421528, 2.02789032, 2.03537414, 1.53242216, 1.98837176,
#        1.62418748, 0.84968151, 0.5659359 , 0.71315433, 1.98330493,
#        2.03444874, 1.80959471, 1.19210644, 1.59487969, 0.82769774,
#        1.72604195, 1.50760119, 1.9445715 , 1.67288484, 0.68547027,
#        1.29769732, 1.2976328 , 1.94900743, 0.82360497, 1.78430886,
#        0.59595101, 1.24124076, 0.66941149, 1.88836055, 1.20122151,
#        0.81462386, 1.02378936, 1.03667035, 1.73416299, 1.68417046,
#        1.17687273, 0.8935109 , 1.97931112, 2.03608244, 1.55422866,
#        1.21541076, 0.54574457, 1.64898923, 1.55405934, 0.68856039,
#        1.6164745 , 0.8286683 , 1.30039002, 1.89902227, 1.17194809,
#        1.49016745, 0.58874344, 0.99887895, 1.7337492 , 1.94531123,
#        1.86492607, 1.43401226, 1.70408578, 0.73917837, 1.37847417,
#        1.9705628 , 1.58570083, 1.08831183, 0.92386703, 1.86240493,
#        1.92652114, 0.90018155, 0.74258527, 1.45283257, 1.58671086,
#        1.62880101, 1.82640596, 1.2588207 , 1.46188318, 1.71024281,
#        0.91688817, 0.61705084, 1.22661381, 1.81117876, 1.02042582,
#        1.94583495, 0.8182557 , 1.25068912, 1.57249074, 0.84116778,
#        0.84065507, 1.76247079, 1.60618606, 0.69236344, 1.01102406,
#        1.28764672, 0.65923787, 1.9615999 , 1.55901488, 1.93448825,
#        1.04898815, 1.3878178 , 1.93275197, 2.02481847, 1.77790179,
#        1.58896539, 1.9713156 , 1.72185546, 0.58769546, 2.03422977,
#        1.23887015, 1.00772213, 1.30858243, 0.68540065, 1.18095155,
#        1.01111729, 1.36622084, 1.34432165, 1.32395623, 0.6741883 ,
#        0.533078  , 1.45948087, 1.86236227, 0.68064849, 0.58684593,
#        0.79570128, 0.81168628, 0.67856401, 2.00712346, 2.01563393,
#        0.64571333, 1.68751892, 0.90771864, 0.56743646, 1.40710766,
#        1.31180421, 1.99558921, 0.76205468, 2.02885724, 0.80399772,
#        1.91148331, 1.84056635, 1.59388605, 1.17947927, 0.91114384,
#        1.897534  , 2.00933278, 1.1963743 , 2.01162988, 1.83345225,
#        1.93787543, 0.87370512, 2.03018135, 1.31099703, 1.16565585,
#        1.5514068 , 1.7766163 , 1.91547111, 1.20676798, 1.03251109,
#        1.00850456, 1.08631664, 1.34445454, 1.68007373, 2.01697303,
#        1.65230119, 1.7996135 , 1.86282785, 0.85387566, 1.17366918,
#        1.91056091, 0.54496044, 0.85685552, 1.200004  , 1.04919458,
#        1.31573697, 1.36287726, 0.54544641, 1.8157929 , 1.18505635,
#        0.97199217, 1.25939111, 1.36482639, 0.79183238, 1.09311416,
#        1.58769766, 0.55761746, 1.48318816, 1.83706532, 2.01502831,
#        1.84013065, 0.84860864, 1.86964903, 1.6377512 , 1.4352516 ,
#        1.3336131 , 1.24593758, 1.71858715, 0.8545697 , 1.20611757,
#        1.10236313, 1.38248585, 1.14265366, 0.61929272, 0.87005743,
#        1.33101598, 0.66131469, 1.90319433, 1.18181302, 1.17066096,
#        1.45543065, 1.11106507, 1.6078587 , 0.84596381, 1.38765528,
#        0.69120365, 0.79641878, 0.58690072, 1.90013504, 1.94818532,
#        0.61156276, 1.90811504, 1.18950914, 1.25792236, 1.6971205 ,
#        1.82568357, 1.83298212, 1.30941018, 1.12218556, 1.70879956,
#        0.69426026, 1.78662382, 0.82863953, 1.28770698, 1.9665401 ,
#        0.90413797, 0.75553472, 0.85579583, 1.65127955, 0.58278804,
#        0.84896678, 1.89806391, 0.58651141, 1.19400031, 0.56417403,
#        0.92681115, 1.01724685, 0.74553281, 1.11384278, 1.02760844,
#        1.73641913, 0.74680023, 1.97921572, 1.52467538, 1.43599315,
#        1.06858768, 2.00126024, 0.89449853, 0.95719603, 1.76849456,
#        1.4139595 , 0.70832801, 1.41355871, 1.54195545, 0.66968952,
#        1.36687266, 1.46447498, 0.70914047, 1.84756145, 1.26214083,
#        1.43409173, 1.4025294 , 1.2931048 , 1.70592252, 1.75203289,
#        1.21524178, 0.99094074, 1.50887199, 2.00684515, 1.84045609,
#        1.58081744, 1.13062975, 0.86445544, 1.19200506, 2.00277509,
#        1.45624853, 1.67070787, 1.03155407, 1.23764762, 1.51063217,
#        1.69507581, 1.94472383, 0.7199019 , 1.20408205, 1.44060199,
#        1.65248104, 1.09005594, 1.53459047, 0.58450893, 0.62014633,
#        0.77369575, 2.00455023, 1.57825539, 0.57638777, 0.79960582,
#        1.49579228, 1.13827125, 1.08793431, 1.00588687, 0.74900219,
#        0.59406736, 1.96707026, 1.43742042, 0.83156406, 1.2141755 ,
#        1.29640406, 1.34951193, 1.12250275, 1.87758631, 0.74664474,
#        0.53376586, 0.54062979, 1.56504704, 1.92926021, 0.73675518,
#        1.66634724, 1.56552093, 1.54718977, 1.73992465, 0.92980714,
#        1.596947  , 1.17084609, 1.0220213 , 1.40097624, 0.50826346,
#        1.77965945, 1.63205419, 1.40721476, 0.67193493, 1.021053  ,
#        0.91093179, 1.23333435, 1.87194381, 1.90186234, 0.58332985,
#        1.61585687, 1.76040005, 0.82400674, 1.22562866, 2.00155866,
#        1.4948172 , 1.07740637, 1.01417133, 1.52454738, 0.66469069,
#        1.93626693, 0.7088402 , 1.65480514, 0.89537047, 1.97582342,
#        1.26896088, 1.05586742, 2.0106502 , 1.23871617, 0.5147734 ,
#        0.91365626, 1.17709872, 1.48395919, 0.89907135, 1.02645181,
#        1.86522089, 1.10696505, 0.95463008, 1.40056498, 1.96360932,
#        1.24868984, 1.53631512, 1.73687433, 1.25400663, 1.21658073,
#        0.98074807, 1.7875705 , 0.87936841, 1.35439595, 0.74955545,
#        1.04499032, 1.81816311, 1.10021033, 1.55649439, 1.10363814,
#        1.59938084, 1.77406286, 0.74572385, 0.89948331, 1.82539354,
#        1.48113301, 0.55580751, 1.29075333, 1.30113465, 1.78266536,
#        1.09810644, 1.94630424, 0.71789849, 1.37103237, 0.9815612 ,
#        0.54201785, 0.83385399, 1.01048893, 0.77793669, 1.56250159,
#        1.15154206, 1.04638149, 1.34034959, 0.65848147, 1.54453169,
#        1.62273249, 0.84105128, 1.41013826, 0.68627502, 0.60360275,
#        1.60782084, 1.67987292, 1.27150555, 1.03656902, 1.92891805,
#        1.78487376, 1.41999495, 0.92248987, 1.97777198, 0.80896093,
#        1.39039404, 1.52837071, 1.27143722, 0.9924921 , 1.27682139,
#        1.73984304, 1.17741596, 0.79860062, 1.13386454, 1.18558712,
#        1.07088201, 1.52372782, 1.63792994, 1.35394736, 1.42282785,
#        1.25959311, 1.46263681, 0.6043711 , 0.61535863, 1.75200517,
#        0.75201139, 0.55473388, 0.66878612, 1.72622758, 1.46759789,
#        1.75126761, 0.80825387, 0.93585194, 1.1728472 , 0.92872218,
#        1.83664666, 0.74948541, 1.2401573 , 1.92729629, 0.89002477,
#        1.21135377, 1.12231196, 1.75844805, 1.24585078, 1.83677918,
#        0.76507417, 0.58248878, 1.44956414, 0.65074779, 0.63648113,
#        1.36841884, 1.23204715, 1.95508112, 0.69731447, 1.15149479,
#        1.69263201, 0.78188859, 1.83462712, 1.32886292, 1.85251262,
#        1.24176195, 1.67892096, 1.04165471, 1.02515076, 1.84800141,
#        1.48900131, 0.75385351, 1.74919459, 1.37951881, 0.95548264,
#        0.93407205, 1.07265307, 1.32356219, 0.8492355 , 1.18841628])

# %% [markdown]
# Математическое ожидание:

# %%
samples.mean()
# Out:
# 1.281401567815057

# %% [markdown]
# Выборочная дисперсия (несмещённая):

# %%
samples.var(ddof=1)
# Out:
# 0.1950333835741427

# %% [markdown]
# #### Задача 2
#
# Рост взрослого населения города X имеет нормальное распределение, причем, средний рост равен 174 см, а среднее квадратическое отклонение равно 8 см. посчитайте, какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# 1. больше 182 см?
# 2. больше 190 см?
# 3. от 166 см до 190 см?
# 4. от 166 см до 182 см?
# 5. от 158 см до 190 см?
# 6. не выше 150 см или не ниже 190 см?
# 7. не выше 150 см или не ниже 198 см?
# 8. ниже 166 см?
#
# Задачу можно решить двумя способами: без использования сторонних библиотек (numpy, scipy, pandas и пр.), а затем проверить себя с помощью встроенных функций

# %% [markdown]
# Поскольку Х - нормально распределенная случайная величина используем формулу для нахождения вероятности попадания НСВ в интервал:

# %% [markdown]
# $$P(\alpha < X < \beta) = \Phi\left(\dfrac{\beta - а}{\sigma}\right) - \Phi\left(\dfrac{\alpha - а}{\sigma}\right)$$

# %% [markdown]
# Где $\Phi(х)$ - функция Лапласа (значения табулированы)

# %% [markdown]
# a = 174, \
# $\sigma = 8$

# %% [markdown]
# P(Х > 182) = 1 - P(Х<182) = 1 - Ф(182-174/8) = 1 - Ф(1) = 1 - 0,8413 = 0,1587

# %%
1 - norm(loc = 174 , scale = 8).cdf(182)
# Out:
# 0.15865525393145707

# %% [markdown]
# P(Х > 190) = 1 - P(Х<190) = 1 - Ф(190-174/8) = 1 - Ф(2) = 1 - 0,9772 = 0,0028

# %%
p = 1 - stats.norm.cdf(x=190, loc=174, scale=8)
p
# Out:
# 0.02275013194817921

# %% [markdown]
# P(166 < Х < 190) = Ф(190-174/8) - Ф(166-174/8) = 0,8185

# %%
p = (stats.norm.cdf(x=190, loc=174, scale=8) - stats.norm.cdf(x=166, loc=174, scale=8))
p
# Out:
# 0.8185946141203637

# %% [markdown]
# P(166 < Х < 182) = Ф(182-174/8) - Ф(166-174/8) = 0,6826

# %%
p = (stats.norm.cdf(x=182, loc=174, scale=8) - stats.norm.cdf(x=166, loc=174, scale=8))
p
# Out:
# 0.6826894921370859

# %% [markdown]
# P(158 < Х < 190) = Ф(190-174/8) - Ф(158-174/8) = 0,9544

# %%
p = (stats.norm.cdf(x=190, loc=174, scale=8) - stats.norm.cdf(x=158, loc=174, scale=8))
p
# Out:
# 0.9544997361036416

# %% [markdown]
# P(Х < 150 | Х > 190) = Ф(150-174/8) + (1-Ф(190-174/8) = 0,0228

# %%
p = stats.norm.cdf(x=150, loc=174, scale=8) + (1 - stats.norm.cdf(x=190, loc=174, scale=8))
p
# Out:
# 0.0241000299798093

# %% [markdown]
# P(Х < 150 | Х > 198) = Ф(150-174/8) + (1-Ф(198-174/8) = 0,0026

# %%
p = stats.norm.cdf(x=150, loc=174, scale=8) + (1 - stats.norm.cdf(x=198, loc=174, scale=8))
p
# Out:
# 0.0026997960632601965

# %% [markdown]
# P(Х < 166) = Ф(166-174/8) = 0,1587

# %%
p = stats.norm.cdf(x=166, loc=174, scale=8)
p
# Out:
# 0.15865525393145707

# %% [markdown]
# #### Задача 3 (Дополнительно)
#
# Коробки с шоколадом упаковываются автоматически. Их средняя масса равна 1.06 кг. Известно, что 5% коробок имеют массу, меньшую 1 кг. Найдите: а) среднее квадратическое отклонение массы коробки, б) процент коробок, имеющих массу больше 1.1 кг.
#
# Подсказка. 1. Можно считать, что распределение массы коробки нормальное. 2. Найдите такое значение scale, для которого значение cdf(x=1, loc=1.06, scale=scale) близко к 0.05. Точности 0.0001 будет достаточно.

# %% [markdown]
# Х - нормально распределенная случайная величина, равная массе коробки с конфетами а=1.06, $\sigma = 8$. Тогда, используя формулу нахождения вероятности попадания нормальной случайной величины в интервал:

# %% [markdown]
# $$P(\alpha < X < \beta) = \Phi\left(\dfrac{\beta - а}{\sigma}\right) - \Phi\left(\dfrac{\alpha - а}{\sigma}\right)$$

# %% [markdown]
# и используя условие, что 5% коробок имеют массу меньшую 1 кг получаем:

# %% [markdown]
# $$P(-\infty < X < 1) = \Phi\left(\dfrac{1 - 1,06}{\sigma}\right) - \Phi\left(\dfrac{-\infty - 1,06}{\sigma}\right) = 0.05$$

# %% [markdown]
# $$\Phi\left(\dfrac{-0,06}{\sigma}\right) - \Phi\left(-\infty\right) = 0.05$$

# %% [markdown]
# $$-\Phi\left(\dfrac{-0,06}{\sigma}\right) +0,5 = 0.05$$

# %% [markdown]
# $$\Phi\left(\dfrac{0,06}{\sigma}\right) = 0.45$$

# %% [markdown]
# $$\dfrac{0,06}{\sigma} = 1.645$$

# %% [markdown]
# $${\sigma} = 0.0365$$

# %%
for scale in np.linspace(0.00001, 1, 99999):
    s = stats.norm.cdf(x=1, loc=1.06, scale=scale)
    if s > 0.0499 and s < 0.0501:
        print(f'Среднее квадратическое отклонение массы коробки: {scale}')
        break
# Out:
# Среднее квадратическое отклонение массы коробки: 0.03646036450729015

# %% [markdown]
#  Вычислим процент коробок, масса которых превышает 1,1 кг

# %% [markdown]
# $$P(1,1 < X < \infty) = \Phi\left(\dfrac{\infty - 1,06}{0,0365}\right) - \Phi\left(\dfrac{1,1 - 1,06}{0,0365}\right) = \Phi\left(\infty\right) - \Phi\left(\dfrac{0,04}{0,0365}\right) = \Phi\left(\infty\right) - \Phi\left(1,095\right)= 1 - 0,8621 = 0,1379$$

# %% [markdown]
# или 13,79%

# %%
p = (stats.norm.cdf(x=float('inf'), loc=1.06, scale=scale) - stats.norm.cdf(x=1.1, loc=1.06, scale=scale))
print(f'Процент коробок, имеющих массу больше 1.1 кг: {round(p*100,3)} %')
# Out:
# Процент коробок, имеющих массу больше 1.1 кг: 13.63 %
